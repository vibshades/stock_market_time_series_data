# %%
import keras
from keras.models import load_model
import random
import numpy as np
import math
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from IPython.display import clear_output
import time
import pandas_datareader as pdr
import pandas_datareader.data as web
from datetime import datetime
import matplotlib.pyplot as plt
import pandas as pd

# %%
# prints formatted price
def formatPrice(n):
	return ("-$" if n < 0 else "$") + "{0:.2f}".format(abs(n))

# %%
def rsi(data,t):
    up=0
    down=0
    window_length = 14
    close = data['Adj Close']
    delta = close.diff()
    for i in range(t-window_length+1,t):
        if delta[i] >0:
            up=up+delta[i]
        else:
            down=down+abs(delta[i])
            
    up=up/window_length
    down=down/window_length
    RS = up / down
    RSI = 100.0 - (100.0 / (1.0 + RS))
    return RSI

# %%
#df_total=pd.read_csv('/home/admin-pc/Desktop/19march/5data/^NSEI.csv')
#df_train=df_total[:1700]
#df_test=df_total[1700:]

# %%
class Portfolio:
    def __init__(self):
        self.cash=1000000
        self.profit=0
        self.inventory = []
        
    def getData(self):        
        self.vec = []
        self.start = datetime(2007, 1, 1)
        self.end = datetime(2019, 3, 3)
        #self.df = web.DataReader('^NSEI', 'yahoo', self.start, self.end)
        self.df=pd.read_csv('/home/admin-pc/Desktop/19march/5data/^NSEI.csv')[:1700]
        return self.df 
    
    def getState(self,data,t):
        self.n=50
        self.res=[]
        for i in range(self.n):
            if ((data['Close'][t-i]-data['Close'][t-i-1])/data['Close'][t-i-1])*100 > 0.25:
                a=1
            elif ((data['Close'][t-i]-data['Close'][t-i-1])/data['Close'][t-i-1])*100 < -0.25:
                a=-1
            else:
                a=0          
            self.res.append(a)
        self.res.append(Portfolio().cash)
        self.res.append(Portfolio().profit)
        return np.array([self.res])

# %%
class RLAgent:
    def __init__(self, model_name=""):
        self.state_size = 52 # normalized previous days
        self.action_size = 3 # sit, buy, sell
        self.memory = deque(maxlen=1000)
        self.nshare=0
        self.last_price=0
        self.model_name = model_name
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.model = self._model()

    def _model(self):
        model = Sequential()
        model.add(Dense(units=64, input_dim=self.state_size, activation="relu"))
        model.add(Dense(units=32, activation="relu"))
        model.add(Dense(units=8, activation="relu"))
        model.add(Dense(self.action_size, activation="linear"))
        model.compile(loss="mse", optimizer=Adam(lr=0.001))

        return model

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)

        options = self.model.predict(state)
        return np.argmax(options[0])

    def expReplay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size + 1, l):
            mini_batch.append(self.memory[i])

        for state, action, reward, next_state, done in mini_batch:
            target = reward
            if not done:
                target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])

            target_f = self.model.predict(state)
            target_f[0][action] = target
            self.model.fit(state, target_f, epochs=1, verbose=0)

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %%
#************************-Training-*********************

rl = RLAgent()
episode_count=100
for e in range(episode_count + 1):
    agent=Portfolio()
    data=agent.getData()
    data['Action']=""
    data['actual_action']=""
    data['share']=""
    data['Cash']=""
    data['trade_profit']=""
    data['Adj_cash']=""
    state=agent.getState(data,51)
    
    l = len(data) - 1
    batch_size = 32
    print( "Episode " + str(e) + "/" + str(episode_count))
    state = agent.getState(data, 51)
    initial_cash=agent.cash
    total_profit = 0
    agent.nshare=0
    agent.last_price=0
    data['Action'][50]=0
    data['share'][50]=agent.nshare
    data['Cash'][50]= agent.cash
    
    for t in range(51,l):
        action = rl.act(state)
        data['Action'][t]=0
        data['share'][t]=agent.nshare
        data['Cash'][t]= agent.cash
        
        
        # sit
        next_state = agent.getState(data, t + 1)
        reward = 0

        if action == 1:# buy
                data['Action'][t]=1
                trend=rsi(data,t)
                if trend <=30:                            
                    if  agent.nshare == 0: 
                        agent.nshare=int(agent.cash/data['Close'][t])
                        agent.cash=agent.cash-agent.nshare*data['Close'][t]
                        agent.last_price=data['Close'][t]
                        data['actual_action'][t]="Bought"
                
                    elif agent.nshare < 0: 
                        sell_price=agent.last_price
                        ns = agent.nshare
                        agent.nshare=0
                        data['trade_profit'][t]=(sell_price - data['Close'][t])*(-ns)
                        total_profit = total_profit + (sell_price - data['Close'][t])*(-ns)
                        agent.cash=agent.cash+(-ns*sell_price)+data['trade_profit'][t]
                        data['actual_action'][t]="Bought"
                
                    data['share'][t]=agent.nshare
                    data['Cash'][t]= agent.cash
                    data['Adj_cash'][t]=agent.cash+agent.nshare*data['Close'][t]
                    reward = (1+((data['Close'][t]-data['Close'][t-1])/data['Close'][t-1])*(data['Close'][t-1]/data['Close'][t-50]))
            
        elif action == 2:# sell
            data['Action'][t]=2
            trend=rsi(data,t)
            if trend >=70:  
                    if  agent.nshare == 0: 
                        agent.nshare=int(agent.cash/data['Close'][t])
                             
                        agent.cash=agent.cash-agent.nshare*data['Close'][t]
                        agent.nshare= -agent.nshare
                        agent.last_price=data['Close'][t]
                        data['actual_action'][t]="Sold"
                                
                    elif agent.nshare > 0: 
                        buy_price=agent.last_price
                        ns = agent.nshare
                        agent.nshare=0
                        data['trade_profit'][t]=(data['Close'][t]-buy_price)*(ns)
                        total_profit = total_profit + (data['Close'][t]-buy_price)*(ns)
                        agent.cash=agent.cash+(ns)*data['Close'][t]
                        data['actual_action'][t]="Sold"
               
                    data['share'][t]=agent.nshare
                    data['Cash'][t]= agent.cash
                    data['Adj_cash'][t]=agent.cash+(-agent.nshare)*agent.last_price+(agent.last_price - data['Close'][t])*(-agent.nshare)
                    reward = -1*(1+((data['Close'][t]-data['Close'][t-1])/data['Close'][t-1])*(data['Close'][t-1]/data['Close'][t-50]))

        done = True if t == l - 1 else False
        rl.memory.append((state, action, reward, next_state, done))
        state = next_state

        if done:
                
                print( "------------------------------------------")
                print ("Initial Cash: " + formatPrice(initial_cash))
                print ("Total  Profit: " + formatPrice(total_profit))
                print ("Final cash: " + formatPrice(agent.cash))
                print ("final holding: {} ".format(agent.nshare))
                print("-------------------------------------------")
            
                
            

        if len(rl.memory) > batch_size:
            rl.expReplay(batch_size)
            
  
    if e % 5 == 0:
        rl.model.save("models/model_ep" + str(e))
        data.to_csv('/home/admin-pc/Desktop/19march/5data/nifty50.csv')
# Out:
# Episode 0/100
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/admin-pc/anaconda/envs/RL/lib/python3.6/site-packages/ipykernel_launcher.py:82: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: -$423191.02
# Final cash: $1613.96
# final holding: 100
# -------------------------------------------
# Episode 1/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $218534.61
# Final cash: $2767.01
# final holding: 219
# -------------------------------------------
# Episode 2/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $355931.93
# Final cash: $5254.25
# final holding: 233
# -------------------------------------------
# Episode 3/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $768127.20
# Final cash: $1768127.20
# final holding: 0
# -------------------------------------------
# Episode 4/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $348092.65
# Final cash: $2950.22
# final holding: 259
# -------------------------------------------
# Episode 5/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $54392.42
# Final cash: $1054392.42
# final holding: 0
# -------------------------------------------
# Episode 6/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $415747.33
# Final cash: $1415747.33
# final holding: 0
# -------------------------------------------
# Episode 7/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $400141.83
# Final cash: $2417.93
# final holding: 243
# -------------------------------------------
# Episode 8/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $252572.39
# Final cash: $2640.02
# final holding: 211
# -------------------------------------------
# Episode 9/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $309486.48
# Final cash: $5124.90
# final holding: 249
# -------------------------------------------
# Episode 10/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $416631.94
# Final cash: $1889.94
# final holding: 271
# -------------------------------------------
# Episode 11/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $42129.08
# Final cash: $485.90
# final holding: 208
# -------------------------------------------
# Episode 12/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $422107.72
# Final cash: $1422107.72
# final holding: 0
# -------------------------------------------
# Episode 13/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $251769.54
# Final cash: $227.54
# final holding: 212
# -------------------------------------------
# Episode 14/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $99579.29
# Final cash: $5974.78
# final holding: -145
# -------------------------------------------
# Episode 15/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $929460.92
# Final cash: $2557.60
# final holding: 335
# -------------------------------------------
# Episode 16/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $0.00
# Final cash: $5119.24
# final holding: 191
# -------------------------------------------
# Episode 17/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: -
100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $843769.59
# Final cash: $1843769.59
# final holding: 0
# -------------------------------------------
# Episode 57/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $381671.96
# Final cash: $4437.91
# final holding: 242
# -------------------------------------------
# Episode 58/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $161599.72
# Final cash: $625.56
# final holding: 204
# -------------------------------------------
# Episode 59/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $432722.22
# Final cash: $4075.22
# final holding: 242
# -------------------------------------------
# Episode 60/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $1471177.97
# Final cash: $2471177.97
# final holding: 0
# -------------------------------------------
# Episode 61/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $583565.39
# Final cash: $3926.92
# final holding: 265
# -------------------------------------------
# Episode 62/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $1017934.87
# Final cash: $2017934.87
# final holding: 0
# -------------------------------------------
# Episode 63/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $322918.61
# Final cash: $3919.56
# final holding: 220
# -------------------------------------------
# Episode 64/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $610139.95
# Final cash: $1610139.95
# final holding: 0
# -------------------------------------------
# Episode 65/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $274539.18
# Final cash: $3358.19
# final holding: 221
# -------------------------------------------
# Episode 66/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $169048.83
# Final cash: $3015.48
# final holding: 238
# -------------------------------------------
# Episode 67/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $502625.66
# Final cash: $4315.66
# final holding: 257
# -------------------------------------------
# Episode 68/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $16926.50
# Final cash: $1864.39
# final holding: 213
# -------------------------------------------
# Episode 69/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $504188.99
# Final cash: $699.34
# final holding: 288
# -------------------------------------------
# Episode 70/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $233688.55
# Final cash: $2274.92
# final holding: 241
# -------------------------------------------
# Episode 71/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $198745.31
# Final cash: $3595.31
# final holding: 205
# -------------------------------------------
# Episode 72/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $343819.87
# Final cash: $2164.17
# final holding: 257
# -------------------------------------------
# Episode 73/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $145705.83
# Final cash: $4168.98
# final holding: 233
# -------------------------------------------
# Episode 74/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $145705.83
# Final cash: $4168.98
# final holding: 233
# -------------------------------------------
# Episode 75/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $420762.33
# Final cash: $1197.98
# final holding: 248
# -------------------------------------------
# Episode 76/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $303098.99
# Final cash: $2468.16
# final holding: 268
# -------------------------------------------
# Episode 77/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $43555.69
# Final cash: $4027.44
# final holding: 181
# -------------------------------------------
# Episode 78/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $4202.00
# Final cash: $3436.54
# final holding: 210
# -------------------------------------------
# Episode 79/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $1007904.21
# Final cash: $5864.56
# final holding: -253
# -------------------------------------------
# Episode 80/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $383848.91
# Final cash: $1383848.91
# final holding: 0
# -------------------------------------------
# Episode 81/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: -$7581.62
# Final cash: $3299.91
# final holding: 207
# -------------------------------------------
# Episode 82/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $632866.60
# Final cash: $1501.76
# final holding: -214
# -------------------------------------------
# Episode 83/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $245227.13
# Final cash: $348.99
# final holding: 269
# -------------------------------------------
# Episode 84/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $0.00
# Final cash: $5119.24
# final holding: 191
# -------------------------------------------
# Episode 85/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $417378.18
# Final cash: $1417378.18
# final holding: 0
# -------------------------------------------
# Episode 86/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: -$314946.58
# Final cash: $3979.03
# final holding: 136
# -------------------------------------------
# Episode 87/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $1005892.09
# Final cash: $65.84
# final holding: -266
# -------------------------------------------
# Episode 88/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $406299.54
# Final cash: $1266.54
# final holding: 238
# -------------------------------------------
# Episode 89/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: -$87810.23
# Final cash: $1969.76
# final holding: 191
# -------------------------------------------
# Episode 90/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $171569.00
# Final cash: $636.34
# final holding: 239
# -------------------------------------------
# Episode 91/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $386001.94
# Final cash: $1052.95
# final holding: 231
# -------------------------------------------
# Episode 92/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $251977.84
# Final cash: $3403.79
# final holding: 262
# -------------------------------------------
# Episode 93/100
# ------------------------------------------
# Initial Cash: $1000000.00
# Total  Profit: $710974.78
# Final cash: $2041.70
# final holding: 313
# -------------------------------------------
# Episode 94/100
